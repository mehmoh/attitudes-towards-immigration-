# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\mehdi\data301\course-project-solo_506-1\data\raw\Data.csv',sep=',',low_memory=False)

# %%
df.head(2)
# Out:
#       cps19_StartDate       cps19_EndDate   cps19_ResponseId  cps19_consent  \
# 0  13sep2019 08:09:44  13sep2019 08:36:19  R_1OpYXEFGzHRUpjM              1
# 1  13sep2019 08:39:09  13sep2019 08:57:06  R_2qdrL3J618rxYW0              1
#
#    cps19_citizenship  cps19_yob  cps19_yob_2001_age  cps19_gender  \
# 0                  4         70                 NaN             2
# 1                  4         79                 NaN             2
#
#    cps19_province  cps19_education  ...  pes19_lived  pes19_follow_pol  \
# 0              24               10  ...          NaN               NaN
# 1              24               10  ...          NaN               NaN
#
#    pes19_lang  pes19_lang_70_TEXT  pes19_lang_84_TEXT  pes19_occ_text  \
# 0         NaN                 NaN                 NaN             NaN
# 1         NaN                 NaN                 NaN             NaN
#
#    pes19_occ_cat  pes19_occ_cat_28_TEXT  pes19_employment  \
# ...

# %%
df.shape
# Out:
# (37822, 471)

# %%
df.describe()
# Out:
#        cps19_consent  cps19_citizenship     cps19_yob  cps19_yob_2001_age  \
# count        37822.0       37822.000000  37822.000000               293.0
# mean             1.0           4.035482     51.308709                 2.0
# std              0.0           0.184997     16.611707                 0.0
# min              1.0           4.000000      1.000000                 2.0
# 25%              1.0           4.000000     38.000000                 2.0
# 50%              1.0           4.000000     51.000000                 2.0
# 75%              1.0           4.000000     65.000000                 2.0
# max              1.0           5.000000     82.000000                 2.0
#
#        cps19_gender  cps19_province  cps19_education  cps19_pos_carbon  \
# count  37822.000000    37822.000000     37822.000000      12549.000000
# mean       1.596531       20.301015         7.411665          3.187346
# std        0.506040        3.757882         1.936421          1.555440
# ...
